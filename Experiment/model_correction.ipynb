# %%
from model import *

# %%
with open("./file/leak_dataset_2018.pickle", "rb") as f:
    leak_dataset_2018 = pickle.load(f)
draw_plot(-leak_dataset_2018['Pressures (m)']['n114'])

# %%
with open("./file/fix_pressure_2018.pickle", "rb") as f:
    fix_pressure_2018 = pickle.load(f)
with open("./file/fix_pressure_2019.pickle", "rb") as f:
    fix_pressure_2019 = pickle.load(f)
with open("./file/pressure_2018.pickle", "rb") as f:
    leak_pressure_2018 = pickle.load(f)
with open("./file/pressure_2019.pickle", "rb") as f:
    leak_pressure_2019 = pickle.load(f)

draw_plot(leak_pressure_2018['n114'],'2018 pressure_diff no correction')
draw_plot(fix_pressure_2018['n114'],'2018 pressure_diff corrected')
draw_plot(fix_pressure_2018['n114'].resample("D").mean(),'2018 pressure_diff day')
draw_plot(leak_pressure_2019['n114'],'2019 pressure_diff no correction')
draw_plot(fix_pressure_2019['n114'],'2019 pressure_diff corrected')
draw_plot(fix_pressure_2019['n114'].resample("D").mean(),'2019 pressure_diff day')
